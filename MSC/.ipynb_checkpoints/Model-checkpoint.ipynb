# %%
import numpy as np
import pandas as pd
import sqlite3

# %% [markdown]
# # Merge

# %%
connection = sqlite3.connect('MSC.db')
cursor = connection.cursor()

sql = ('''Select 
            main.date,
            top1,top2,top3,top4,top5,
            top6,top7,top8,top9,top10,
            top11,top12,top13,top14,top15,
            top16,top17,top18,top19,top20,
            top21,top22,top23,top24,top25,
            top26,top27,top28,top29,top30,
            
            DJI_Open,
            DJI_High,
            DJI_Low,
            DJI_Close,
            DJI_Adj_Close,
            
            SP500_Open,
            SP500_High,
            SP500_Low,
            SP500_Close,
            SP500_Adj_Close

            from main
            left join DJI on
            main.date = date(DJI.Date)
            left join SP500 on
            main.date = date(SP500.Date)
            
            --where DJI_Open not NULL
            order by main.date

       ''')
df = pd.read_sql_query(sql,connection)
print(df.shape)
df.tail()
# Out:
# (136, 41)
#            date                                               top1  \
# 131  2021-05-13  'Champions League of tax avoidance:' Uber used...
# 132  2021-05-14  "2 for 100, 3 for 75." - Israeli soldier posts...
# 133  2021-05-15  123,000 death certificates issued in last 71 d...
# 134  2021-05-16  Israel has given a “warning” that it will bomb...
# 135  2021-05-17  Italian port workers refuse arms shipment to I...
#
#                                                   top2  \
# 131  Animals to be formally recognised as sentient ...
# 132  67 killed in Gaza, 7 killed in Israel as UN wa...
# 133  Pro-Palestinian rally in Paris banned amid ris...
# 134  Al Jazeeera office in Gaza destroyed by Israel...
# 135  South African government calls for Israel to b...
#
#                                                   top3  \
# 131  'We're watching a lynching': Jewish crowd in I...
# 132  Israel's bombing of Gaza apartment buildings c...
# 133  The UN says 10,000 Palestinians have been forc...
# 134  The suicide of a 17-year-old girl who accused ...
# 135  The Suez Canal will be widened by 131 feet to ...
#
#                                                   top4  \
# 131  Israeli flags burned outside 2 German synagogu...
# 132  Israel's Israeli Arab member of parliament Aid...
# 133  Egypt declares state of readiness in hospitals...
# 134  The Associated Press pushes back on Israel's c...
# 135  Top Indian virologist quits government panel w...
#
#                                                   top5  \
# 131  Putin’s Wagner Group mercenaries ‘killed kids,...
# 132  Jews and Arabs start to push back against viol...
# 133  Brits urged to drink 124 pints each to help st...
# 134  Pfizer makes billions from COVID-19 vaccines, ...
# 135  Israeli warplanes struck roads leading to main...
#
#                                                   top6  \
# 131  Shark Advocates Cheer UK’s Banning Of Shark Fi...
# 132  France asks police to ban pro-Palestinian Pari...
# 133  Chinese Billionaire Arrested And Business Seiz...
# 134  Israel argues tower it bombed housing reporter...
# 135  UK withholds backing for Joe Biden’s minimum g...
#
#                                                   top7  \
# 131  Ethereum creator Vitalik Buterin donates $1 bi...
# 132  US withdraws 120 military personnel from Israe...
# 133  Palestinians flee as Israeli artillery pounds ...
# 134  Israel's Defense Minister Benny Gantz: "If cit...
# 135  ‘Victims of aggression’: Gaza hospital overwhe...
#
#                                                   top8  \
# 131  Dead whale found with 16kg of plastic bags, wr...
# 132  Israel steps up Gaza offensive, kills senior H...
# 133  Russian Journalist Who Exposed Oil-Theft Schem...
# 134  Thousands join London march in solidarity with...
# 135  Turkey proposes protection force for Palestine...
#
#                                                   top9  ...   DJI_Open  \
# 131  Israel rejects Hamas truce offer; ministers vo...  ...  33,624.74
# 132  Biden says he's not seen a 'significant overre...  ...  34,050.86
# 133  Hamas scrambles to learn how Israel killed its...  ...       None
# 134  Germany will not tolerate ‘anti-Semitic’ prote...  ...       None
# 135  25 arrested in Delhi for posters criticising P...  ...       None
#
#       DJI_High    DJI_Low  DJI_Close DJI_Adj_Close SP500_Open SP500_High  \
# 131  34,181.77  33,623.49  34,021.45     34,021.45   4,074.99   4,131.58
# 132  34,454.05  34,050.86  34,382.13     34,382.13   4,129.58   4,183.13
# 133       None       None       None          None       None       None
# 134       None       None       None          None       None       None
# 135       None       None       None          None       None       None
#
#     SP500_Low SP500_Close SP500_Adj_Close
# 131  4,074.99    4,112.50        4,112.50
# 132  4,129.58    4,173.85        4,173.85
# 133      None        None            None
# 134      None        None            None
# 135      None        None            None
#
# [5 rows x 41 columns]

# %% [markdown]
# for i  in df.iloc[135]:
#     print(i)
#     print()

# %%
connection = sqlite3.connect('MSC.db')
cursor = connection.cursor()

sql = ('''Select * from main
    order by date
       ''')
df = pd.read_sql_query(sql,connection)
print(df.shape)
df.tail()
# Out:
# (136, 31)
#            date                                               top1  \
# 131  2021-05-13  'Champions League of tax avoidance:' Uber used...
# 132  2021-05-14  "2 for 100, 3 for 75." - Israeli soldier posts...
# 133  2021-05-15  123,000 death certificates issued in last 71 d...
# 134  2021-05-16  Israel has given a “warning” that it will bomb...
# 135  2021-05-17  Italian port workers refuse arms shipment to I...
#
#                                                   top2  \
# 131  Animals to be formally recognised as sentient ...
# 132  67 killed in Gaza, 7 killed in Israel as UN wa...
# 133  Pro-Palestinian rally in Paris banned amid ris...
# 134  Al Jazeeera office in Gaza destroyed by Israel...
# 135  South African government calls for Israel to b...
#
#                                                   top3  \
# 131  'We're watching a lynching': Jewish crowd in I...
# 132  Israel's bombing of Gaza apartment buildings c...
# 133  The UN says 10,000 Palestinians have been forc...
# 134  The suicide of a 17-year-old girl who accused ...
# 135  The Suez Canal will be widened by 131 feet to ...
#
#                                                   top4  \
# 131  Israeli flags burned outside 2 German synagogu...
# 132  Israel's Israeli Arab member of parliament Aid...
# 133  Egypt declares state of readiness in hospitals...
# 134  The Associated Press pushes back on Israel's c...
# 135  Top Indian virologist quits government panel w...
#
#                                                   top5  \
# 131  Putin’s Wagner Group mercenaries ‘killed kids,...
# 132  Jews and Arabs start to push back against viol...
# 133  Brits urged to drink 124 pints each to help st...
# 134  Pfizer makes billions from COVID-19 vaccines, ...
# 135  Israeli warplanes struck roads leading to main...
#
#                                                   top6  \
# 131  Shark Advocates Cheer UK’s Banning Of Shark Fi...
# 132  France asks police to ban pro-Palestinian Pari...
# 133  Chinese Billionaire Arrested And Business Seiz...
# 134  Israel argues tower it bombed housing reporter...
# 135  UK withholds backing for Joe Biden’s minimum g...
#
#                                                   top7  \
# 131  Ethereum creator Vitalik Buterin donates $1 bi...
# 132  US withdraws 120 military personnel from Israe...
# 133  Palestinians flee as Israeli artillery pounds ...
# 134  Israel's Defense Minister Benny Gantz: "If cit...
# 135  ‘Victims of aggression’: Gaza hospital overwhe...
#
#                                                   top8  \
# 131  Dead whale found with 16kg of plastic bags, wr...
# 132  Israel steps up Gaza offensive, kills senior H...
# 133  Russian Journalist Who Exposed Oil-Theft Schem...
# 134  Thousands join London march in solidarity with...
# 135  Turkey proposes protection force for Palestine...
#
#                                                   top9  ...  \
# 131  Israel rejects Hamas truce offer; ministers vo...  ...
# 132  Biden says he's not seen a 'significant overre...  ...
# 133  Hamas scrambles to learn how Israel killed its...  ...
# 134  Germany will not tolerate ‘anti-Semitic’ prote...  ...
# 135  25 arrested in Delhi for posters criticising P...  ...
#
#                                                  top21  \
# 131  World Health Organisation should have declared...
# 132  Catholic Church investigating claims children ...
# 133  India COVID cases above 24 million as mutant s...
# 134      Family of 10 killed in Israeli strike on Gaza
# 135  US for 3rd time blocking Security Council join...
#
#                                                  top22  \
# 131  Boris Johnson urges Israel and Palestinians to...
# 132  Israel rejects Egypt's ceasefire proposal for ...
# 133  Man arrested for riding in back seat of driver...
# 134  Police fire water cannon at pro-Palestinian de...
# 135  Gaza ‘days away’ from near total blackout as f...
#
#                                                  top23  \
# 131  Thirty more Palestinian civilians are killed a...
# 132     Azerbaijani forces 'advance 3 km into Armenia'
# 133  Wales to launch Universal Basic Income Pilot S...
# 134  Heavy rocket barrage on central Israel, Taiybe...
# 135  UK PM Johnson: Britain's Jews should not have ...
#
#                                                  top24  \
# 131  Gaza rocket kills 6-year-old boy in Israel's S...
# 132  Bolsonaro's approval falls to 24%, the lowest ...
# 133  IDF Military Intelligence knew Hamas would fir...
# 134  Malaysia calls for immediate UN Security Counc...
# 135  Islamic nations hold emergency summit on Israe...
#
#                                                  top25  \
# 131  Covid pandemic was preventable, says WHO-commi...
# 132  Bertrand Heilbronn, head of a Palestine Solida...
# 133                           China has landed on Mars
# 134  After speaking with Biden, Netanyahu suggests ...
# 135  France for 1st time takes part in Japan, U.S. ...
#
#                                                  top26  \
# 131  Cameroon jails transgender women for 'attempte...
# 132  Investigation: Dozens of Vancouver care homes ...
# 133  Lies on Social Media Inflame Israeli-Palestini...
# 134       Morocco dispatches humanitarian help to gaza
# 135  Germany's Greens plan to cut jet fuel subsidie...
#
#                                                  top27  \
# 131  Israel names four Hamas commanders killed in G...
# 132  Reuters: Mosques disappear as China strives to...
# 133  Israel-Gaza: Strike collapses building during ...
# 134  In Indian State of Uttar Pradesh Over 2000 Dea...
# 135  China Calls For UN Intervention For De-Escalat...
#
#                                                  top28  \
# 131  Chief rabbi pans Jewish violence: 'We must be ...
# 132  Scottish independence referendum to go ahead w...
# 133  U.S. puts brake on U.N. statement over Middle ...
# 134  Users on Instagram, Twitter, TikTok decry cens...
# 135  Kashmir police arrest graffiti artist over Pal...
#
#                                                  top29  \
# 131  B.C. to refuse driver’s licence renewals to pe...
# 132  US Secretary of State says Australia will not ...
# 133  China says its first Mars landing — of both a ...
# 134  Israeli airstrike on Gaza claims eight young c...
# 135  Netanyahu says military campaign will continue...
#
#                                                  top30
# 131  Former Myanmar Beauty Queen Takes up Arms Agai...
# 132  US says Xinjiang is essentially an 'open-air p...
# 133  An Israeli airstrike on a house in Gaza City h...
# 134  Arab world condemns Israeli violence, but take...
# 135  Tiny traces of DNA found in cave dust may unlo...
#
# [5 rows x 31 columns]

# %%
connection = sqlite3.connect('MSC.db')
cursor = connection.cursor()

sql = ('''Select * from prices
          order by date, symbol
       ''')
df = pd.read_sql_query(sql,connection)
print(df.shape)
df.tail(507)
# Out:
# (50002, 8)
#                       date       open       high        low      close  \
# 49495  2021-05-14 00:00:00     130.47     131.69     130.45     131.15
# 49496  2021-05-14 00:00:00      21.43      22.48      21.43      22.40
# 49497  2021-05-14 00:00:00     205.76     206.46     201.14     202.81
# 49498  2021-05-14 00:00:00     126.25     127.89     125.85     127.45
# 49499  2021-05-14 00:00:00     117.36     117.59     116.38     116.43
# ...                    ...        ...        ...        ...        ...
# 49997  2021-05-14 00:00:00     476.84     487.86     475.73     486.73
# 49998  2021-05-14 00:00:00      59.32      60.36      58.72      60.20
# 49999  2021-05-14 00:00:00     171.71     172.98     170.85     172.29
# 50000  2021-05-14 00:00:00  34,050.86  34,454.05  34,050.86  34,382.13
# 50001  2021-05-14 00:00:00   4,129.58   4,183.13   4,129.58   4,173.85
#
#        adj_close         volume symbol
# 49495     131.15        775,100      A
# 49496      22.40     39,133,600    AAL
# 49497     202.81        602,500    AAP
# 49498     127.45     81,806,500   AAPL
# 49499     116.43      6,268,100   ABBV
# ...          ...            ...    ...
# 49997     486.73        239,500   ZBRA
# 49998      60.20      1,015,100   ZION
# 49999     172.29      1,232,600    ZTS
# 50000  34,382.13    303,230,000   ^DJI
# 50001   4,173.85  3,251,920,000  ^GSPC
#
# [507 rows x 8 columns]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob

# %%
Anakin = SentimentIntensityAnalyzer()
Anakin.polarity_scores(" ")
# Out:
# {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}

# %%
def detect_subjectivity(text):
    '''
    subjectivity is a float within the range [0.0, 1.0] where 0.0 is very objective and 1.0 is very subjective.
    '''
    return TextBlob(text).sentiment.subjectivity

detect_subjectivity(" ") #should return 0
# Out:
# 0.0

# %%
#get the name of the headline columns
cols = []
for i in range(1,31):
    col = ("top{}".format(i))
    cols.append(col)
    
for col in cols:
    df[col] = df[col].astype(str) # Make sure data is treated as a string
    df[col+'_comp']= df[col].apply(lambda x:Anakin.polarity_scores(x)['compound'])
    df[col+'_sub'] = df[col].apply(detect_subjectivity)
    print("{} Done".format(col))
# Out:
# top1 Done
# top2 Done
# top3 Done
# top4 Done
# top5 Done
# top6 Done
# top7 Done
# top8 Done
# top9 Done
# top10 Done
# top11 Done
# top12 Done
# top13 Done
# top14 Done
# top15 Done
# top16 Done
# top17 Done
# top18 Done
# top19 Done
# top20 Done
# top21 Done
# top22 Done
# top23 Done
# top24 Done
# top25 Done
# top26 Done
# top27 Done
# top28 Done
# top29 Done
# top30 Done

# %%
#the text isn't required anymore
df = df.drop(cols,axis=1)
df.tail()
# Out:
#          date   DJI_Open   DJI_High    DJI_Low  DJI_Close DJI_Adj_Close  \
# 0  2021-01-04  30,627.47  30,674.28  29,881.82  30,223.89     30,223.89
# 1  2021-01-05  30,204.25  30,504.89  30,141.78  30,391.60     30,391.60
# 2  2021-01-06  30,362.78  31,022.65  30,313.07  30,829.40     30,829.40
# 3  2021-01-07  30,901.18  31,193.40  30,897.86  31,041.13     31,041.13
# 4  2021-01-08  31,069.58  31,140.67  30,793.27  31,097.97     31,097.97
#
#   SP500_Open SP500_High SP500_Low SP500_Close  ... top26_comp  top26_sub  \
# 0   3,764.61   3,769.99  3,662.71    3,700.65  ...     0.0000   0.333333
# 1   3,698.02   3,737.83  3,695.07    3,726.86  ...     0.0000   0.000000
# 2   3,712.20   3,783.04  3,705.34    3,748.14  ...     0.0000   0.400000
# 3   3,764.71   3,811.55  3,764.71    3,803.79  ...     0.4404   0.000000
# 4   3,815.05   3,826.69  3,783.60    3,824.68  ...    -0.7964   0.000000
#
#    top27_comp  top27_sub  top28_comp  top28_sub  top29_comp  top29_sub  \
# 0      0.6597   0.100000     -0.7351   0.250000     -0.3400   0.600000
# 1      0.0000   0.000000     -0.7269   0.025000      0.4019   0.050000
# 2      0.0000   0.000000     -0.5256   0.975000     -0.6124   0.375000
# 3      0.4215   0.454545      0.0000   0.066667      0.0000   0.333333
# 4      0.0000   0.000000      0.0000   0.000000      0.0000   0.500000
#
#    top30_comp  top30_sub
# 0      0.2023       0.00
# 1     -0.4215       0.00
# 2     -0.2960       0.55
# 3      0.5859       0.00
# 4      0.3400       0.00
#
# [5 rows x 71 columns]

# %%
comp_cols = [col + "_comp" for col in cols]

w = np.arange(1,31,1).tolist()
w.reverse()

weighted_comp = []
max_comp = []
min_comp = []
for i in range(0,len(df)):
    a = df.loc[i,comp_cols].tolist()
    weighted_comp.append(np.average(a, weights=w))
    max_comp.append(max(a))
    min_comp.append(min(a))
    
df['compound_mean'] = weighted_comp
df['compound_max'] = max_comp
df['compound_min'] = min_comp

sub_cols = [col + "_sub" for col in cols]

weighted_sub = []
max_sub = []
min_sub = []
for i in range(0,len(df)):
    a = df.loc[i,sub_cols].tolist()
    weighted_sub.append(np.average(a, weights=w))
    max_sub.append(max(a))
    min_sub.append(min(a))

df['subjectivity_mean'] = weighted_sub
df['subjectivity_max'] = max_sub
df['subjectivity_min'] = min_sub

to_drop = sub_cols+comp_cols
df = df.drop(to_drop, axis=1)

# %%
df.tail()
# Out:
#           date   DJI_Open   DJI_High    DJI_Low  DJI_Close DJI_Adj_Close  \
# 87  2021-05-10  34,785.27  35,091.56  34,741.57  34,742.82     34,742.82
# 88  2021-05-11  34,572.74  34,572.74  34,075.31  34,269.16     34,269.16
# 89  2021-05-12  34,206.40  34,207.87  33,555.22  33,587.66     33,587.66
# 90  2021-05-13  33,624.74  34,181.77  33,623.49  34,021.45     34,021.45
# 91  2021-05-14  34,050.86  34,454.05  34,050.86  34,382.13     34,382.13
#
#    SP500_Open SP500_High SP500_Low SP500_Close SP500_Adj_Close  compound_mean  \
# 87   4,228.29   4,236.39  4,188.13    4,188.43        4,188.43      -0.380386
# 88   4,150.34   4,162.04  4,111.53    4,152.10        4,152.10      -0.295928
# 89   4,130.55   4,134.73  4,056.88    4,063.04        4,063.04      -0.347254
# 90   4,074.99   4,131.58  4,074.99    4,112.50        4,112.50      -0.111215
# 91   4,129.58   4,183.13  4,129.58    4,173.85        4,173.85      -0.411042
#
#     compound_max  compound_min  subjectivity_mean  subjectivity_max  \
# 87        0.8176       -0.9735           0.194761          1.000000
# 88        0.6931       -0.8876           0.135567          0.666667
# 89        0.5859       -0.8834           0.194080          0.778571
# 90        0.6369       -0.8555           0.106260          0.700000
# 91        0.4588       -0.9485           0.171641          1.000000
#
#     subjectivity_min
# 87               0.0
# 88               0.0
# 89               0.0
# 90               0.0
# 91               0.0

# %%
import plotly.graph_objects as go

fig3 = go.Figure()
fig3.add_trace(go.Scatter(x=df.date, y=df.subjectivity_mean,
                    mode='lines',
                    name='Mean'))
fig3.add_trace(go.Scatter(x=df.date, y=df.subjectivity_min,
                    mode='lines',
                    name='Min'))
fig3.add_trace(go.Scatter(x=df.date, y=df.subjectivity_max,
                    mode='lines',
                    name='Max'))
title = []
title.append(dict(xref='paper', yref='paper', x=0.0, y=1.05,
                              xanchor='left', yanchor='bottom',
                              text='Development of subjectivity score',
                              font=dict(family='Arial',
                                        size=30,
                                        color='rgb(37,37,37)'),
                              showarrow=False))
fig3.update_layout(xaxis_title='Date',
                   yaxis_title='Subjectivity score',
                  annotations=title)
fig3.show()
